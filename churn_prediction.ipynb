# %%
#IMPORTING LIBRARIES
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

#IMPORTING DATASET
df = pd.read_csv('Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
# SHAPE OF THE DATASET
df.shape
# Out:
# (10000, 14)

# %%
# INFORMATION ABOUT THE DATASET
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# TOP 5 ROWS
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# BOTTOM 5 ROWS
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
# DESCRIPTION OF  DATASET
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
# CHECKING NULL VALUES
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# DROPPING
df.dropna(inplace = True)

# %%
#DROPPING ID COLOUMN
df.drop('RowNumber',axis = 1,inplace = True)
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0          0.00              1          1               1        101348.88
# 1      83807.86              1          0               1        112542.58
# 2     159660.80              3          1               0        113931.57
# 3          0.00              2          0               0         93826.63
# 4     125510.82              1          1               1         79084.10
# ...         ...            ...        ...             ...              ...
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 13 columns]

# %%
#DROPPING ID COLOUMN
df.drop('Surname',axis = 1,inplace = True)
df
# Out:
#       CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0       15634602          619    France  Female   42       2       0.00
# 1       15647311          608     Spain  Female   41       1   83807.86
# 2       15619304          502    France  Female   42       8  159660.80
# 3       15701354          699    France  Female   39       1       0.00
# 4       15737888          850     Spain  Female   43       2  125510.82
# ...          ...          ...       ...     ...  ...     ...        ...
# 9995    15606229          771    France    Male   39       5       0.00
# 9996    15569892          516    France    Male   35      10   57369.61
# 9997    15584532          709    France  Female   36       7       0.00
# 9998    15682355          772   Germany    Male   42       3   75075.31
# 9999    15628319          792    France  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                 1          1               1        101348.88       1
# 1                 1          0               1        112542.58       0
# 2                 3          1               0        113931.57       1
# 3                 2          0               0         93826.63       0
# 4                 1          1               1         79084.10       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0         96270.64       0
# 9996              1          1               1        101699.77       0
# 9997              1          0               1         42085.58       1
# 9998              2          1               0         92888.52       1
# 9999              1          1               0         38190.78       0
#
# [10000 rows x 12 columns]

# %%
#DROPPING ID COLOUMN
df.drop('CustomerId',axis = 1,inplace = True)
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
# CHECKING DUPLICATES
df.duplicated().sum()
# Out:
# 0

# %%
# DROPPING DUPLICATE VALUES
df.drop_duplicates(inplace = True)

# %%
# FINDING UNIQUE VALUES
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# FINDING UNIQUE VALUES
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
# MAPPING STRING VALUES TO INTEGER
df['Gender'] = df['Gender'].map({'Male':0,'Female':1})
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       1   42       2       0.00              1
# 1             608     Spain       1   41       1   83807.86              1
# 2             502    France       1   42       8  159660.80              3
# 3             699    France       1   39       1       0.00              2
# 4             850     Spain       1   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       0   39       5       0.00              2
# 9996          516    France       0   35      10   57369.61              1
# 9997          709    France       1   36       7       0.00              1
# 9998          772   Germany       0   42       3   75075.31              2
# 9999          792    France       1   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
# MAPPING STRING VALUES TO INTEGER
df['Geography'] = df['Geography'].map({'France':0,'Spain':1,'Germany':2})
df
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       1   42       2       0.00              1
# 1             608          1       1   41       1   83807.86              1
# 2             502          0       1   42       8  159660.80              3
# 3             699          0       1   39       1       0.00              2
# 4             850          1       1   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       0   39       5       0.00              2
# 9996          516          0       0   35      10   57369.61              1
# 9997          709          0       1   36       7       0.00              1
# 9998          772          2       0   42       3   75075.31              2
# 9999          792          0       1   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
# BOXPLOT FOR EACH COLUMN
plt.figure(figsize = (10,5))
sb.boxplot(data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
# REMOVING OUTLIERS
#for i in df.columns:
 #q3 = df[i].quantile(0.75)
  #iqr = q3 - q1
  #upper = q3+1.5*iqr
  #lower = q1-1.5*iqr
  #df = df[(df[i]>=lower) & (df[i]<=upper)]

# %%
# BOXPLOT FOR EACH COLUMN
plt.figure(figsize = (10,5))
sb.boxplot(data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
# SCATTERPLOT FOR EACH COLUMN
plt.figure(figsize = (10,5))
sb.scatterplot(data = df)
plt.show()

# %%
# DIVIDING DATASET INTO X AND Y
x=df.drop('Exited',axis=1)
x
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       1   42       2       0.00              1
# 1             608          1       1   41       1   83807.86              1
# 2             502          0       1   42       8  159660.80              3
# 3             699          0       1   39       1       0.00              2
# 4             850          1       1   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       0   39       5       0.00              2
# 9996          516          0       0   35      10   57369.61              1
# 9997          709          0       1   36       7       0.00              1
# 9998          772          2       0   42       3   75075.31              2
# 9999          792          0       1   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
# DIVIDING DATASET INTO X AND Y
y=df['Exited']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %% [markdown]
# ###LOGISTIC REGRESSION

# %%
# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 9254          686          0       0   32       6       0.00              2
# 1561          632          2       0   42       4  119624.60              2
# 1670          559          1       0   24       3  114739.92              1
# 6087          561          0       1   27       9  135637.00              1
# 6669          517          0       0   56       9  142147.32              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 5734          768          0       0   54       8   69712.74              1
# 5191          682          0       1   58       1       0.00              1
# 5390          735          0       1   38       1       0.00              3
# 860           667          0       0   43       8  190227.46              1
# 7270          697          2       0   51       1  147910.30              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 9254          1               1        179093.26
# 1561          1               1        195978.86
# 1670          1               0         85891.02
# 6087          1               0        153080.40
# 6669          0               0         39488.04
# ...         ...             ...              ...
# 5734          1               1         69381.05
# 5191          1               1           706.50
# 5390          0               0         92220.12
# 860           1               0         97508.04
# 7270          1               1         53581.14
#
# [8000 rows x 10 columns]

# %%
y_train
# Out:
# 9254    0
# 1561    0
# 1670    1
# 6087    1
# 6669    1
#        ..
# 5734    0
# 5191    0
# 5390    1
# 860     1
# 7270    0
# Name: Exited, Length: 8000, dtype: int64

# %%
# BUILDING THE LOGISTIC REGRESSION MODEL
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# PREDICTION BY THE MODEL
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
a = confusion_matrix(y_test,y_pred)
print("Accuracy Score : ", (accuracy_score(y_test,y_pred)*100))
print(classification_report(y_test,y_pred))
print(sb.heatmap(a,annot=True))
# Out:
# Accuracy Score :  80.05
#               precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89      1607
#            1       0.46      0.08      0.14       393
#
#     accuracy                           0.80      2000
#    macro avg       0.64      0.53      0.51      2000
# weighted avg       0.74      0.80      0.74      2000
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ###MULTI-CLASSIFICATION

# %%
# HEATMAP OF THE DATASET
plt.figure(figsize = (10,5))
sb.heatmap(df.corr(),annot = True)
plt.show()

# %%
# DIVIDING DATASET INTO X AND Y
x=df.drop('Gender',axis=1)
x
# Out:
#       CreditScore  Geography  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0   42       2       0.00              1
# 1             608          1   41       1   83807.86              1
# 2             502          0   42       8  159660.80              3
# 3             699          0   39       1       0.00              2
# 4             850          1   43       2  125510.82              1
# ...           ...        ...  ...     ...        ...            ...
# 9995          771          0   39       5       0.00              2
# 9996          516          0   35      10   57369.61              1
# 9997          709          0   36       7       0.00              1
# 9998          772          2   42       3   75075.31              2
# 9999          792          0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 10 columns]

# %%
# DIVIDING DATASET INTO X AND Y
y=df['Gender']
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    0
# 9999    1
# Name: Gender, Length: 10000, dtype: int64

# %%
# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
# BUILDING THE LOGISTIC REGRESSION MODEL
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# PREDICTION BY THE MODEL
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score,f1_score
a = confusion_matrix(y_test,y_pred)
mc_accuracy = (accuracy_score(y_test,y_pred)*100)
mc_precision = precision_score(y_test,y_pred,average='micro')
mc_recall = recall_score(y_test,y_pred,average='micro')
mc_f1 = f1_score(y_test,y_pred,average='micro')
print("Accuracy Score : ", accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
print(sb.heatmap(a,annot=True))
# Out:
# Accuracy Score :  54.75
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71      1095
#            1       0.50      0.01      0.01       905
#
#     accuracy                           0.55      2000
#    macro avg       0.52      0.50      0.36      2000
# weighted avg       0.53      0.55      0.39      2000
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ###DECISION TREE CLASSIFIER

# %%
# PREDICTION BY THE MODEL
from sklearn.tree import DecisionTreeClassifier
treemodel = DecisionTreeClassifier()
treemodel.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# PLOTTING THE DECISION TREE OF THE DATASET
from sklearn import tree
plt.figure(figsize = (15,10))
tree.plot_tree(treemodel,filled = True)
plt.show()

# %%
# PREDICTION BY THE MODEL
y_pred = treemodel.predict(x_test)
y_pred
# Out:
# array([0, 1, 0, ..., 1, 0, 1])

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
a = confusion_matrix(y_test,y_pred,)
dtc_accuracy = (accuracy_score(y_test,y_pred)*100)
dtc_precision = precision_score(y_test,y_pred,average='micro')
dtc_recall = recall_score(y_test,y_pred,average='micro')
dtc_f1 = f1_score(y_test,y_pred,average='micro')
print(accuracy_score(y_test,y_pred))
print("Accuracy Score : ", accuracy_score(y_test,y_pred)*100)
print(classification_report(y_test,y_pred))
print(sb.heatmap(a,annot=True))
# Out:
# 0.5175
# Accuracy Score :  51.74999999999999
#               precision    recall  f1-score   support
#
#            0       0.56      0.57      0.56      1095
#            1       0.47      0.45      0.46       905
#
#     accuracy                           0.52      2000
#    macro avg       0.51      0.51      0.51      2000
# weighted avg       0.52      0.52      0.52      2000
#
# Axes(0.125,0.11;0.62x0.77)

# %% [markdown]
# ###RANDOM FOREST CLASSIFIER

# %%
# BUILDING THE RANDOM FOREST MODEL
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50,random_state = 42)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=42)

# %%
# PREDICTION BY THE MODEL
y_pred=rf.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
a = confusion_matrix(y_test,y_pred)
rfc_accuracy = (accuracy_score(y_test,y_pred)*100)
rfc_precision = precision_score(y_test,y_pred,average='micro')
rfc_recall = recall_score(y_test,y_pred,average='micro')
rfc_f1 = f1_score(y_test,y_pred,average='micro')
print(accuracy_score(y_test,y_pred))
print(sb.heatmap(a,annot = True))
print(classification_report(y_test,y_pred))
# Out:
# 0.5315
# Axes(0.125,0.11;0.62x0.77)
#               precision    recall  f1-score   support
#
#            0       0.56      0.68      0.61      1095
#            1       0.48      0.35      0.40       905
#
#     accuracy                           0.53      2000
#    macro avg       0.52      0.52      0.51      2000
# weighted avg       0.52      0.53      0.52      2000

# %% [markdown]
# ###K-NEAREST NEIGHBORS

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)
y_pred+
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
# DETERMINING ACCURACY OF THE MODEL
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score,f1_score
y_pred = knn.predict(x_test)
knn_accuracy =( accuracy_score(y_test,y_pred)*100)
knn_precision = precision_score(y_test,y_pred,average='micro')
knn_recall = recall_score(y_test,y_pred,average='micro')
knn_f1 = f1_score(y_test,y_pred,average='micro')
print("ACCURACY SCORE : ", knn_accuracy)
print(sb.heatmap(confusion_matrix(y_test,y_pred),annot = True))
print(classification_report(y_test,y_pred))
# Out:
# ACCURACY SCORE :  49.2
# Axes(0.125,0.11;0.62x0.77)
#               precision    recall  f1-score   support
#
#            0       0.53      0.57      0.55      1095
#            1       0.43      0.40      0.42       905
#
#     accuracy                           0.49      2000
#    macro avg       0.48      0.48      0.48      2000
# weighted avg       0.49      0.49      0.49      2000

# %% [markdown]
# ###NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()

#fitting-
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
#predicting
y_pred=gnb.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
y_pred = gnb.predict(x_test)
nvb_accuracy = (accuracy_score(y_test,y_pred)*100)
nvb_precision = precision_score(y_test,y_pred,average='micro')
nvb_recall = recall_score(y_test,y_pred,average='micro')
nvb_f1 = f1_score(y_test,y_pred,average='micro')
print("ACCURACY SCORE : ", nvb_accuracy)
print(sb.heatmap(confusion_matrix(y_test,y_pred),annot = True))
print(classification_report(y_test,y_pred))
# Out:
# ACCURACY SCORE :  54.300000000000004
# Axes(0.125,0.11;0.62x0.77)
#               precision    recall  f1-score   support
#
#            0       0.55      0.95      0.70      1095
#            1       0.45      0.05      0.09       905
#
#     accuracy                           0.54      2000
#    macro avg       0.50      0.50      0.39      2000
# weighted avg       0.50      0.54      0.42      2000

# %% [markdown]
# ###SUPPORT VECTOR MACHINE

# %%
 from sklearn.svm import SVC
 svm = SVC(C=1, gamma = 0.0001, kernel = 'linear')
 svm.fit(x_train,y_train)
# Out:
# SVC(C=1, gamma=0.0001, kernel='linear')

# %%
 y_pred = svm.predict(x_test)
 y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
 svm_accuracy = accuracy_score(y_test,y_pred)
 svm_precision = precision_score(y_test,y_pred,average = 'micro')
 svm_recall = recall_score(y_test,y_pred,average = 'micro')
 svm_f1 = f1_score(y_test,y_pred,average = 'micro')
 print("ACCURACY SCORE : ", svm_accuracy)
 print(sb.heatmap(confusion_matrix(y_test,y_pred),annot = True))
 print(classification_report(y_test,y_pred))
# Out:
# ACCURACY SCORE :  0.5425
# Axes(0.125,0.11;0.62x0.77)
#               precision    recall  f1-score   support
#
#            0       0.55      0.96      0.70      1095
#            1       0.44      0.04      0.07       905
#
#     accuracy                           0.54      2000
#    macro avg       0.49      0.50      0.38      2000
# weighted avg       0.50      0.54      0.41      2000

# %%
a = pd.DataFrame({'Model' : ['Logistic Regression','Decision Tree','Random Forest','KNN','Naive Bayes','SVM'],
                  'Accuracy' : [mc_accuracy,dtc_accuracy,rfc_accuracy,knn_accuracy,nvb_accuracy,svm_accuracy],
                  'Precision' : [mc_precision,dtc_precision,rfc_precision,knn_precision,nvb_precision,svm_precision],
                  'Recall' : [mc_recall,dtc_recall,rfc_recall,knn_recall,nvb_recall,svm_recall],
                  'F-1 Score' : [mc_f1,dtc_f1,rfc_f1,knn_f1,nvb_f1,svm_f1]})

a.style.set_table_styles([{'selector' : '',
                            'props' : [('border',
                                        '1px solid black')]}])
# Out:
# <style type="text/css">
# #T_700ac  {
#   border: 1px solid black;
# }
# </style>
# <table id="T_700ac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_700ac_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_700ac_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_700ac_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_700ac_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_700ac_level0_col4" class="col_heading level0 col4" >F-1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_700ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_700ac_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_700ac_row0_col1" class="data row0 col1" >54.750000</td>
#       <td id="T_700ac_row0_col2" class="data row0 col2" >0.547500</td>
#       <td id="T_700ac_row0_col3" class="data row0 col3" >0.547500</td>
#       <td id="T_700ac_row0_col4" class="data row0 col4" >0.547500</td>
#     </tr>
#     <tr>
#       <th id="T_700ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_700ac_row1_col0" class="data row1 col0" >Decision Tree</td>
#       <td id="T_700ac_row1_col1" class="data row1 col1" >51.750000</td>
#       <td id="T_700ac_row1_col2" class="data row1 col2" >0.517500</td>
#       <td id="T_700ac_row1_col3" class="data row1 col3" >0.517500</td>
#       <td id="T_700ac_row1_col4" class="data row1 col4" >0.517500</td>
#     </tr>
#     <tr>
#       <th id="T_700ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_700ac_row2_col0" class="data row2 col0" >Random Forest</td>
#       <td id="T_700ac_row2_col1" class="data row2 col1" >53.150000</td>
#       <td id="T_700ac_row2_col2" class="data row2 col2" >0.531500</td>
#       <td id="T_700ac_row2_col3" class="data row2 col3" >0.531500</td>
#       <td id="T_700ac_row2_col4" class="data row2 col4" >0.531500</td>
#     </tr>
#     <tr>
#       <th id="T_700ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_700ac_row3_col0" class="data row3 col0" >KNN</td>
#       <td id="T_700ac_row3_col1" class="data row3 col1" >49.200000</td>
#       <td id="T_700ac_row3_col2" class="data row3 col2" >0.492000</td>
#       <td id="T_700ac_row3_col3" class="data row3 col3" >0.492000</td>
#       <td id="T_700ac_row3_col4" class="data row3 col4" >0.492000</td>
#     </tr>
#     <tr>
#       <th id="T_700ac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_700ac_row4_col0" class="data row4 col0" >Naive Bayes</td>
#       <td id="T_700ac_row4_col1" class="data row4 col1" >54.300000</td>
#       <td id="T_700ac_row4_col2" class="data row4 col2" >0.543000</td>
#       <td id="T_700ac_row4_col3" class="data row4 col3" >0.543000</td>
#       <td id="T_700ac_row4_col4" class="data row4 col4" >0.543000</td>
#     </tr>
#     <tr>
#       <th id="T_700ac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_700ac_row5_col0" class="data row5 col0" >SVM</td>
#       <td id="T_700ac_row5_col1" class="data row5 col1" >0.542500</td>
#       <td id="T_700ac_row5_col2" class="data row5 col2" >0.542500</td>
#       <td id="T_700ac_row5_col3" class="data row5 col3" >0.542500</td>
#       <td id="T_700ac_row5_col4" class="data row5 col4" >0.542500</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize = (10,5))
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Model Accuracy")
plt.bar_label(plt.bar(a['Model'],a['Accuracy']))
plt.bar(a['Model'],a['Accuracy'],color = ['r','g','b','y','c','m'])
plt.show()
